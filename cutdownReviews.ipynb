# %% [markdown]
# # Overview
#
# This notebook creates `.parquet` files from the raw JSON data and metadata. It is provided for reference only, as the output files are included in the referenced `.zip` file.

# %% [markdown]
# # Load `.json` Files into Lists
#
# The data selected for this is the "Tools and Home Improvement" category, both [reviews](https://datarepo.eng.ucsd.edu/mcauley_group/data/amazon_v2/categoryFiles/Tools_and_Home_Improvement.json.gz) and [metadata](https://datarepo.eng.ucsd.edu/mcauley_group/data/amazon_v2/metaFiles2/meta_Tools_and_Home_Improvement.json.gz).
#
# This notebook assumes these are in files named `reviews.json.gz` and `metadata.json.gz`, and in the same directory as this notebook.

# %%
import gzip
import json

data = []
with gzip.open('reviews.json.gz') as f:
    for l in f:
        data.append(json.loads(l.strip()))
        
metadata = []
with gzip.open('metadata.json.gz') as f:
    for l in f:
        metadata.append(json.loads(l.strip()))

# %% [markdown]
# # Load Data into Dataframe
# We'll load this into a dataframe, and remove all records that do not have values for `reviewText`.

# %%
# Load the data to dataframes
import pandas as pd

df = pd.DataFrame.from_dict(data)
df = df[df['reviewText'].notna()]

df_meta=pd.DataFrame.from_dict(metadata)

# the details column is generally all '{}' and causes problems when saving to .parquet file. We don't need it, so drop it.
df_meta = df_meta.drop(columns=['details'])

# %% [markdown]
# # Sample the Data
#
# Rather than maintain all records, we'll keep only the ten products with the most reviews.

# %%
# Identify the top 10 asin values by review count
top_10_asins = df.groupby('asin')['overall'].count().sort_values(ascending=False).head(10).index

# Filter the original dataframe to only include rows with those asin values
df = df[df['asin'].isin(top_10_asins)]
df_meta = df_meta[df_meta['asin'].isin(top_10_asins)]

df
# Out:
#          overall  verified   reviewTime      reviewerID        asin  \
# 1383593      5.0      True   11 6, 2008  A2DY2ODHK5WU9M  B0011UIPIW
# 1383594      3.0      True   11 2, 2008  A2ACQZSJ1TC0AU  B0011UIPIW
# 1383595      5.0     False  10 18, 2008  A1YDAP0AZ9NMYP  B0011UIPIW
# 1383596      5.0      True   10 3, 2008  A2H5KASDT2SZIV  B0011UIPIW
# 1383597      5.0     False  09 14, 2008  A2SH6A32BE6NEV  B0011UIPIW
# ...          ...       ...          ...             ...         ...
# 8806614      4.0      True   09 9, 2018  A25TJVHF90A5D3  B018Z0TE3K
# 8806615      4.0     False   09 9, 2018  A2NYFO70F01ODU  B018Z0TE3K
# 8806616      1.0      True   09 9, 2018  A1AAH4PH22JAPU  B018Z0TE3K
# 8806617      5.0      True   09 8, 2018  A1B1F7SN935GW5  B018Z0TE3K
# 8806618      1.0      True   09 7, 2018   AENUWCWZV4617  B018Z0TE3K
#
#                                              style    reviewerName  \
# 1383593  {'Color:': ' Black', 'Style:': ' Single'}        J. Yates
# 1383594  {'Color:': ' Black', 'Style:': ' Single'}  Dorbel Tweeter
# 1383595  {'Color:': ' Black', 'Style:': ' Single'}         Eric C.
# 1383596  {'Color:': ' Black', 'Style:': ' Single'}         Jeff H.
# 1383597  {'Color:': ' Black', 'Style:': ' Single'}     Comp Expert
# ...                                            ...             ...
# 8806614                                        NaN         clayton
# 8806615                                        NaN          Mrs. K
# 8806616                                        NaN           Brian
# 8806617                                        NaN           Iscos
# 8806618                                        NaN    Dora M. Pais
#
#                                                 reviewText  \
# 1383593  Got this as a promo with the Streamlight head ...
# 1383594  That pretty much says it all for me.  It's an ...
# 1383595  This little light has a sturdy metal design, n...
# 1383596  This tiny light is a beacon of hope in a dark ...
# 1383597  This nanolight is extremely tiny and so makes ...
# ...                                                    ...
# 8806614  I like this for the toilet but it could be som...
# 8806615  We purchased the glowbowl as we were starting ...
# 8806616  This item is terrible. It only worked for like...
# 8806617  It a great product works well my kids love it ...
# 8806618  This product quit working after 2 weeks..All i...
#
#                                                    summary  unixReviewTime  \
# 1383593                                         Best ever!      1225929600
# 1383594  Very bright & tiny - but requires two hands to...      1225584000
# 1383595                                  Good Little Light      1224288000
# 1383596                             Like a shining star...      1222992000
# 1383597  Wonderfully bright, compact, weighs next to no...      1221350400
# ...                                                    ...             ...
# 8806614        Not as bright as the picture shows it to be      1536451200
# 8806615     Product has issues, but great customer service      1536451200
# 8806616                               Not worth the money.      1536451200
# 8806617                   That works very well no issues .      1536364800
# 8806618                                        Do not buy!      1536278400
#
#         vote image
# 1383593  NaN   NaN
# 1383594  122   NaN
# 1383595    6   NaN
# 1383596    4   NaN
# 1383597    2   NaN
# ...      ...   ...
# 8806614  NaN   NaN
# 8806615  NaN   NaN
# 8806616  NaN   NaN
# 8806617  NaN   NaN
# 8806618  NaN   NaN
#
# [90667 rows x 12 columns]

# %% [markdown]
# # Add a "Truncated" Column
#
# We'll not create embeddings for the full review, just the first 400 characters.

# %%
# Truncate the reviewText to 400 characters, and add a new column 'truncated'
max_text_length=400
def truncate_review(text):
    return text[:max_text_length]

df['truncated']=df.apply(lambda row: truncate_review(row['reviewText']),axis=1)

# %% [markdown]
# # Save Parquet Files
#
# With the main selection work done, we'll save the data as parquet files for use in the next notebook.

# %%
# save to parquet files
df.to_parquet('reviews.parquet.gz', compression='gzip')
df_meta.to_parquet('metadata.parquet.gz', compression='gzip')
